# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhid3/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/Python_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("MP1 starting")
# Out:
# MP1 starting

# %% [markdown]
# Problem 1: Introduction on first day of job

# %%
# storing variables
name = "Shubhi"
city = "Lucknow"
birthyear= 2003
age=  2026-2003  # calculating age based on current year

print ("Hello!", "My name is", name,"." "I belong to the city of", city, "." "I will turn", age, "this year." )
# Out:
# Hello! My name is Shubhi .I belong to the city of Lucknow .I will turn 23 this year.

# %% [markdown]
# Problem 2: Currency exchange for Japan trip

# %%
inr_amount= 75000
exchange_rate= 1.75 #exchange rate of Rs 1 to yen
total_yen= (inr_amount*1.75)
print (float(total_yen))
print ("Rs 75000 coverts to 131250.00")
# Out:
# 131250.0
# Rs 75000 coverts to 131250.00

# %% [markdown]
# Problem 3: Grocery Bill

# %%
# storing variables

bread= 40
milk = 65.50
eggs = 120
total= (bread+milk+eggs) #adding total cost of items
avg_total= total/ 3 #calculating average per item

print (total)
print (avg_total)
new_avg= round(avg_total, 2)
print (new_avg)
# Out:
# 225.5
# 75.16666666666667
# 75.17

# %% [markdown]
# Problem 4: Odd or even

# %%
number= 99
is_even= False
print ("Is 99 even?", is_even)
# Out:
# Is 99 even? False

# %% [markdown]
# Problem 5: Password strength check

# %%
password= "hello@1234"
length_ok= 10
contains_at= "@" in password
password_strength= True

if length_ok >=8 and contains_at:
  print("Password", password)
  print("Length OK (>= 8): True", length_ok)
  print("Contains '@':", contains_at)
  print("Strong:", password_strength)
# Out:
# Password hello@1234
# Length OK (>= 8): True 10
# Contains '@': True
# Strong: True

# %% [markdown]
# Problem 6: Class Roster

# %%
#storing attendees names

attendees= ["tom", "daisy", "lily", "clyde", "payal", "neha", "arti", "arya"]

print (len(attendees)) # printing total number of attendees
print (attendees[0]) #printing 1st attendee
print (attendees[6:8]) # printing last two attendees
sorted_attendees= sorted(attendees) [:3] #sorting first three names alphabetically
print (sorted_attendees)
# Out:
# 8
# tom
# ['arti', 'arya']
# ['arti', 'arya', 'clyde']

# %% [markdown]
# Problem 7: Contact Book

# %%
contact_book= {"Arya": 7893046293,
               "Arti": 5730405838,
               "Daisy":9399472984,
               "Mansi":8947473884,
               "Sheena":9984727383}
print ("Arya's phone number is", contact_book["Arya"])
contact_book["Shubhi"]= 7478393948
print (len(contact_book))
print ("Total number of contacts after adding Shubhi is", (len(contact_book)))
# Out:
# Arya's phone number is 7893046293
# 6
# Total number of contacts after adding Shubhi is 6

# %% [markdown]
# Problem 8: Squares of even numbers

# %%
for n in range (1, 21):
  if n % 2 == 0:
    print (n ** 2)
# Out:
# 4
# 16
# 36
# 64
# 100
# 144
# 196
# 256
# 324
# 400

# %% [markdown]
# Problem 9: Sort products by price

# %%
products = [("Notebook", 250),("Pen", 20),("Backpack", 1800),("Eraser", 15),("Water Bottle", 350),]
sorted_products = sorted(products, key= lambda x:x [1])
print ("Sorted List", sorted_products)
# Out:
# Sorted List [('Eraser', 15), ('Pen', 20), ('Notebook', 250), ('Water Bottle', 350), ('Backpack', 1800)]
